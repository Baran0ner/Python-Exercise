# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt

# %%
numpyDizisi1= np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2=numpyDizisi1**2

# %%
(beninFigure, benimEksen) = plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2, color="#5C5861",alpha =0.4)
benimEksen.plot(numpyDizisi2,numpyDizisi1,color="#5CC661",linewidth=0.9, linestyle="--")

# %%
#scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# #histogram

# %%
yeniDizi =np.random.randint(0,100,50)

# %%
plt.hist(yeniDizi)
# Out:
# (array([6., 4., 5., 4., 3., 7., 7., 7., 0., 7.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #boxplot

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9da5b5dc0>,
#   <matplotlib.lines.Line2D at 0x1f9da5b5fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f9da5b6360>,
#   <matplotlib.lines.Line2D at 0x1f9da5b65d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9da5b5ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f9da5b6900>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f9da5b6bd0>],
#  'means': []}
